# %% [markdown]
# <a href="https://colab.research.google.com/github/96jayy/Jung-Minjae/blob/real-estate/%EB%B6%80%EB%8F%99%EC%82%B0%EC%95%84%EC%9D%B4%EB%94%94%EC%96%B4%EA%B3%B5%EB%AA%A8%EC%A0%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
e2207=pd.read_csv('/content/drive/MyDrive/부동산/ES1001AD00101MM2207_csv.csv',sep='|')
e2208=pd.read_csv('/content/drive/MyDrive/부동산/ES1001AD00101MM2208_csv.csv',sep='|')
e2209=pd.read_csv('/content/drive/MyDrive/부동산/ES1001AD00101MM2209_csv.csv',sep='|')
e2210=pd.read_csv('/content/drive/MyDrive/부동산/ES1001AD00101MM2210_csv.csv',sep='|')
e2211=pd.read_csv('/content/drive/MyDrive/부동산/ES1001AD00101MM2211_csv.csv',sep='|')
e2212=pd.read_csv('/content/drive/MyDrive/부동산/ES1001AD00101MM2212_csv.csv',sep='|')
e2301=pd.read_csv('/content/drive/MyDrive/부동산/ES1001AD00101MM2301_csv.csv',sep='|')
e2302=pd.read_csv('/content/drive/MyDrive/부동산/ES1001AD00101MM2302_csv.csv',sep='|')
e2303=pd.read_csv('/content/drive/MyDrive/부동산/ES1001AD00101MM2303_csv.csv',sep='|')
e2304=pd.read_csv('/content/drive/MyDrive/부동산/ES1001AD00101MM2304_csv.csv',sep='|')
e2305=pd.read_csv('/content/drive/MyDrive/부동산/ES1001AD00101MM2305_csv.csv',sep='|')
e2306=pd.read_csv('/content/drive/MyDrive/부동산/ES1001AD00101MM2306_csv.csv',sep='|')

# %%
e2207.columns
# Out:
# Index(['BSDI_NO', 'BSDI_NM', 'CTPR_CD', 'CTPR_NM', 'SIGNGU_CD', 'SIGNGU_NM',
#        'BSDI_TODB_CNT', 'BSDI_COCFC_CNT', 'BSDI_CTCFC_CNT', 'BSDI_CTAFC_CNT',
#        'BSDI_RGFC_CNT', 'BSDI_SLFC_CNT', 'BSDI_MLFLT_CNT', 'BSDI_ERFC_CNT',
#        'BSDI_TNFC_CNT', 'BSDI_SPFC_CNT', 'BSDI_ACMT_CNT', 'BSDI_RCFC_CNT',
#        'BSDI_GAS_TOUQ', 'BSDI_ELEC_TOUQ', 'CMBD_GAS_USQNT', 'CMBD_ELEC_USQNT',
#        'CRDNT', 'DATA_STRD_DT'],
#       dtype='object')

# %%
e2207.columns=e2306.columns

# %%
energy=pd.concat([e2207,e2208,e2209,e2210,e2211,e2212,e2301,e2302,e2303,e2304,e2305,e2306])

# %%
energy.columns
# Out:
# Index(['BSDI_NO', 'BSDI_NM', 'CTPR_CD', 'CTPR_NM', 'SIGNGU_CD', 'SIGNGU_NM',
#        'BSDI_TODB_CNT', 'BSDI_COCFC_CNT', 'BSDI_CTCFC_CNT', 'BSDI_CTAFC_CNT',
#        'BSDI_RGFC_CNT', 'BSDI_SLFC_CNT', 'BSDI_MLFLT_CNT', 'BSDI_ERFC_CNT',
#        'BSDI_TNFC_CNT', 'BSDI_SPFC_CNT', 'BSDI_ACMT_CNT', 'BSDI_RCFC_CNT',
#        'BSDI_GAS_TOUQ', 'BSDI_ELEC_TOUQ', 'CMBD_GAS_USQNT', 'CMBD_ELEC_USQNT',
#        'CRDNT', 'DATA_STRD_DT', 'TRDAR_NO', 'TRDAR_NM',
#        'TRDAR_ISE_TOTL_BILD_CNT', 'TRDAR_ISE_1KIND_NGHBRHD_LVLH_FCLTY_CNT',
#        'TRDAR_ISE_2KIND_NGHBRHD_LVLH_FCLTY_CNT',
#        'TRDAR_ISE_CLTUR_AND_MTNG_FCLTY_CNT', 'TRDAR_ISE_RLGN_LVLH_FCLTY_CNT',
#        'TRDAR_ISE_NTSL_FCLTY_CNT', 'TRDAR_ISE_MLFLT_CNT',
#        'TRDAR_ISE_OVNTY_FCLTY_CNT', 'TRDAR_ISE_NVTT_FCLTY_CNT',
#        'TRDAR_ISE_EXRCS_FCLTY_CNT', 'TRDAR_ISE_ACMT_CNT',
#        'TRDAR_ISE_WAF_FCLTY_CNT', 'TRDAR_ISE_GAS_TOTL_USQNT',
#        'TRDAR_ISE_FTRM_TOTL_USQNT', 'CMRC_PUP_BULD_GAS_USQNT',
# ...

# %%
energy.CTPR_NM.unique()
# Out:
# array(['제주특별자치도', '경상남도', '경상북도', '전라남도', '전라북도', '충청남도', '충청북도', '강원도',
#        '경기도', '세종특별자치시', '울산광역시', '대전광역시', '광주광역시', '인천광역시', '대구광역시',
#        '부산광역시', '서울특별시', '강원특별자치도'], dtype=object)

# %%
e_seoul=energy[energy['CTPR_NM']=='서울특별시']

# %%
e_used=e_seoul.groupby('SIGNGU_NM').mean().loc[:,['TRDAR_ISE_GAS_TOTL_USQNT','TRDAR_ISE_FTRM_TOTL_USQNT']]
# Out:
# <ipython-input-104-59b1d5f1de2e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   e_used=e_seoul.groupby('SIGNGU_NM').mean().loc[:,['TRDAR_ISE_GAS_TOTL_USQNT','TRDAR_ISE_FTRM_TOTL_USQNT']]

# %%
plt.figure(figsize=(40,10))
sns.relplot(e_used,kind='line')
plt.xticks(rotation=90)
plt.show()

# %%
sns.lineplot(e_seoul.groupby('SIGNGU_NM').count().iloc[:,1]/12)
plt.xticks(rotation=90)
plt.show()

# %%
mul2209=pd.read_csv('/content/drive/MyDrive/부동산/ES1012AK00101MM2209_csv.csv')
mul2210=pd.read_csv('/content/drive/MyDrive/부동산/ES1012AK00101MM2210_csv.csv')
mul2211=pd.read_csv('/content/drive/MyDrive/부동산/ES1012AK00101MM2211_csv.csv')
mul2212=pd.read_csv('/content/drive/MyDrive/부동산/ES1012AK00101MM2212_csv.csv')
mul2301=pd.read_csv('/content/drive/MyDrive/부동산/ES1012AK00101MM2301_csv.csv')
mul2302=pd.read_csv('/content/drive/MyDrive/부동산/ES1012AK00101MM2302_csv.csv')
mul2303=pd.read_csv('/content/drive/MyDrive/부동산/ES1012AK00101MM2303_csv.csv')
mul2304=pd.read_csv('/content/drive/MyDrive/부동산/ES1012AK00101MM2304_csv.csv')

# %%
det2209=pd.read_csv('/content/drive/MyDrive/부동산/ES1012AM00101MM2209_csv.csv')
det2210=pd.read_csv('/content/drive/MyDrive/부동산/ES1012AM00101MM2210_csv.csv')
det2211=pd.read_csv('/content/drive/MyDrive/부동산/ES1012AM00101MM2211_csv.csv',low_memory=False)
det2212=pd.read_csv('/content/drive/MyDrive/부동산/ES1012AM00101MM2212_csv.csv',low_memory=False)
det2301=pd.read_csv('/content/drive/MyDrive/부동산/ES1012AM00101MM2301_csv.csv')
det2302=pd.read_csv('/content/drive/MyDrive/부동산/ES1012AM00101MM2302_csv.csv')
det2303=pd.read_csv('/content/drive/MyDrive/부동산/ES1012AM00101MM2303_csv.csv')
det2304=pd.read_csv('/content/drive/MyDrive/부동산/ES1012AM00101MM2304_csv.csv')

# %%
det2209.columns
# Out:
# Index(['DTCHDHS_MTHT_CONV_RT_INFO_NO', 'SIDO_NM', 'SIGNGU_NM', 'TNSHP_NM',
#        'EMD_NM', 'NRB_ROAD_BT_CONT', 'CNTRCT_DIMS_SQM_VL', 'CNTRCT_YM',
#        'CNTRCT_DE', 'MTHT_GTN', 'MNTH_RENTCG', 'BILDNG_YR', 'CNTRCT_CLSF_NM',
#        'AVE_LFSTS_PC_MINM_AMT', 'AVE_LFSTS_PC_MAX_AMT', 'MTHT_CONV_RT_MINM_VL',
#        'MTHT_CONV_RT_MAX_VL'],
#       dtype='object')

# %%
det2301.columns
# Out:
# Index(['DTCHDHS_MTHT_CONV_RT_INFO_NO', 'SIDO_NM', 'SIGNGU_NM', 'TNSHP_NM',
#        'EMD_NM', 'NRB_ROAD_BT_CONT', 'CNTRCT_DIMS_SQM_VL', 'CNTRCT_YM',
#        'CNTRCT_DE', 'MTHT_GTN', 'MNTH_RENTCG', 'BILDNG_YR', 'CNTRCT_CLSF_NM',
#        'AVE_LFSTS_PC_MINM_AMT', 'AVE_LFSTS_PC_MAX_AMT', 'MTHT_CONV_RT_MINM_VL',
#        'MTHT_CONV_RT_MAX_VL'],
#       dtype='object')

# %%
multi=pd.concat([mul2209,mul2210,mul2211,mul2212,mul2301,mul2302,mul2303,mul2304])

# %%
detach=pd.concat([det2209,det2210,det2211,det2212,det2301,det2302,det2303,det2304])

# %%
mul_seoul=multi[multi['SIDO_NM']=='서울특별시']

# %%
mul_seoul['MTHT_GTN']=mul_seoul['MTHT_GTN'].replace(',','',regex=True).map(int)
# Out:
# <ipython-input-12-89f3facedfad>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mul_seoul['MTHT_GTN']=mul_seoul['MTHT_GTN'].replace(',','',regex=True).map(int)

# %%
mul_seoul.columns
# Out:
# Index(['RHMH_HOUSE_MTHT_CONV_RATE_INFO_NO', 'SIDO_NM', 'SIGNGU_NM', 'TNSHP_NM',
#        'EMD_NM', 'HONO_NM', 'SMOEU', 'CNTRCT_YM', 'CNTRCT_DE', 'MTHT_GTN',
#        'MNTH_RENTCG', 'FLR', 'BILDNG_YR', 'CNTRCT_CLSF_NM', 'SUSAR_NM',
#        'NMHSH', 'AVE_LFSTS_PC_MINM_AMT', 'AVE_LFSTS_PC_MAX_AMT',
#        'MTHT_CONV_RT_MINM_VL', 'MTHT_CONV_RT_MAX_VL'],
#       dtype='object')

# %%
cha_seoul=mul_seoul.groupby(['SIGNGU_NM','EMD_NM']).mean().loc[:,['MTHT_GTN','MNTH_RENTCG']]
# Out:
# <ipython-input-13-4a680f115619>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   cha_seoul=mul_seoul.groupby(['SIGNGU_NM','EMD_NM']).mean().loc[:,['MTHT_GTN','MNTH_RENTCG']]

# %%
mul_s_df
# Out:
#     SIGNGU_NM EMD_NM      CG_TYPE          CG
# 0         강남구    개포동     MTHT_GTN  238.829953
# 1         강남구    논현동     MTHT_GTN  156.985975
# 2         강남구    대치동     MTHT_GTN  194.363844
# 3         강남구    도곡동     MTHT_GTN  293.286344
# 4         강남구    삼성동     MTHT_GTN  151.786773
# ..        ...    ...          ...         ...
# 635       중랑구    면목동  MNTH_RENTCG    2.084306
# 636       중랑구     묵동  MNTH_RENTCG    1.536383
# 637       중랑구    상봉동  MNTH_RENTCG    2.101832
# 638       중랑구    신내동  MNTH_RENTCG    1.018987
# 639       중랑구    중화동  MNTH_RENTCG    1.691295
#
# [640 rows x 4 columns]

# %%
cha_seoul
# Out:
#                     MTHT_GTN  MNTH_RENTCG
# SIGNGU_NM EMD_NM
# 강남구       개포동     238.829953     2.008268
#           논현동     156.985975     3.015428
#           대치동     194.363844     2.319756
#           도곡동     293.286344     2.144934
#           삼성동     151.786773     2.352452
# ...                      ...          ...
# 중랑구       면목동     181.632492     2.084306
#           묵동      209.964657     1.536383
#           상봉동     248.510989     2.101832
#           신내동     243.898734     1.018987
#           중화동     171.607143     1.691295
#
# [320 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
GTN=StandardScaler().fit_transform(np.array(mul_s_df[mul_s_df['CG_TYPE']=='MTHT_GTN']['CG']).reshape(-1,1))
RENTCG=StandardScaler().fit_transform(np.array(mul_s_df[mul_s_df['CG_TYPE']=='MNTH_RENTCG']['CG']).reshape(-1,1))

# %%
cha_seoul_trans=pd.concat([pd.DataFrame(GTN),pd.DataFrame(RENTCG)],axis=1).set_index(cha_seoul.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-57c16d3fffad> in <cell line: 1>()
# ----> 1 cha_seoul_trans=pd.concat([pd.DataFrame(GTN),pd.DataFrame(RENTCG)],axis=1).set_index(cha_seoul.index)
#
# NameError: name 'GTN' is not defined

# %%
cha_seoul_trans.columns=['GTN','RENTCG']

# %%
sns.relplot(cha_seoul_trans,kind='line')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
est4=pd.read_csv('/content/drive/MyDrive/부동산/부동산 시세와 면적(전용면적,분양면적 등)_아파트외_서울 (1).csv',sep='|')
est3=pd.read_csv('/content/drive/MyDrive/부동산/부동산 시세와 면적(전용면적,분양면적 등)_아파트외_서울 (2).csv',sep='|')
est2=pd.read_csv('/content/drive/MyDrive/부동산/부동산 시세와 면적(전용면적,분양면적 등)_아파트외_서울 (3).csv',sep='|')
est1=pd.read_csv('/content/drive/MyDrive/부동산/부동산 시세와 면적(전용면적,분양면적 등)_아파트외_서울.csv',sep='|')
# Out:
# <ipython-input-16-ef24fe2c54f1>:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   est4=pd.read_csv('/content/drive/MyDrive/부동산/부동산 시세와 면적(전용면적,분양면적 등)_아파트외_서울 (1).csv',sep='|')
# <ipython-input-16-ef24fe2c54f1>:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   est3=pd.read_csv('/content/drive/MyDrive/부동산/부동산 시세와 면적(전용면적,분양면적 등)_아파트외_서울 (2).csv',sep='|')
# <ipython-input-16-ef24fe2c54f1>:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   est2=pd.read_csv('/content/drive/MyDrive/부동산/부동산 시세와 면적(전용면적,분양면적 등)_아파트외_서울 (3).csv',sep='|')
# <ipython-input-16-ef24fe2c54f1>:4: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
est1=est1[est1['CTPR_NM']=='서울특별시']
est2=est2[est2['CTPR_NM']=='서울특별시']
est3=est3[est3['CTPR_NM']=='서울특별시']
est4=est4[est4['CTPR_NM']=='서울특별시']

# %%
est1['CTPR_NM'][1].split(' ',)
# Out:
# ['서울특별시']

# %%
est1.head()
# Out:
#   CTPR_CD CTPR_NM  SIGNGU_CD  SIGNGU_NM  LEGALDONG_CD  LEGALDONG_NM  PLOT_YN  \
# 0      11   서울특별시    11110.0  서울특별시 종로구       11100.0           NaN      1.0
# 1      11   서울특별시    11110.0  서울특별시 종로구       11100.0           NaN      1.0
# 2      11   서울특별시    11110.0  서울특별시 종로구       11100.0           NaN      1.0
# 3      11   서울특별시    11110.0  서울특별시 종로구       11100.0           NaN      1.0
# 4      11   서울특별시    11110.0  서울특별시 종로구       11100.0           NaN      1.0
#
#    HMNO_LTNO  HSNO_LTNO             LNNO_ADRES  ...  LTOUT_DIMS  PLOT_DIMS  \
# 0       19.0       35.0  서울특별시 종로구 옥인동 19-35번지  ...       68.07        0.0
# 1       19.0       35.0  서울특별시 종로구 옥인동 19-35번지  ...       68.07        0.0
# 2       19.0       35.0  서울특별시 종로구 옥인동 19-35번지  ...       74.17        0.0
# 3       19.0       35.0  서울특별시 종로구 옥인동 19-35번지  ...       74.17        0.0
# 4       19.0       35.0  서울특별시 종로구 옥인동 19-35번지  ...       74.17        0.0
#
# ...

# %%
sns.lineplot(est1.groupby('SIGNGU_NM').mean().ESTT_CURPRC_SMNT_AMT)
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-20-ed7fec6a53a8>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.lineplot(est1.groupby('SIGNGU_NM').mean().ESTT_CURPRC_SMNT_AMT)

# %%
sns.lineplot(est2.groupby('SIGNGU_NM').mean().ESTT_CURPRC_SMNT_AMT)
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-33-2ab9922a6222>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.lineplot(est2.groupby('SIGNGU_NM').mean().ESTT_CURPRC_SMNT_AMT)

# %%
sns.lineplot(est3.groupby('SIGNGU_NM').mean().ESTT_CURPRC_SMNT_AMT)
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-34-6b89bec82046>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.lineplot(est3.groupby('SIGNGU_NM').mean().ESTT_CURPRC_SMNT_AMT)

# %%
sns.lineplot(est4.groupby('SIGNGU_NM').mean().ESTT_CURPRC_SMNT_AMT)
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-35-71334d9bf990>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.lineplot(est4.groupby('SIGNGU_NM').mean().ESTT_CURPRC_SMNT_AMT)

# %%
est=pd.concat([est1,est2,est3,est4],axis=0).reset_index()

# %%
est4.columns
# Out:
# Index(['CTPR_CD', 'CTPR_NM', 'SIGNGU_CD', 'SIGNGU_NM', 'LEGALDONG_CD',
#        'LEGALDONG_NM', 'PLOT_YN', 'HMNO_LTNO', 'HSNO_LTNO', 'LNNO_ADRES',
#        'XU_DIMS', 'LTOUT_DIMS', 'PLOT_DIMS', 'DONG_NM', 'BULD_FLR_NO', 'HO_NM',
#        'LA', 'LO', 'ESTT_CURPRC_SMNT_AMT', 'IMG_COURS', 'DATA_STRD_YM'],
#       dtype='object')

# %%
est.columns
# Out:
# Index(['index', 'CTPR_CD', 'CTPR_NM', 'SIGNGU_CD', 'SIGNGU_NM', 'LEGALDONG_CD',
#        'LEGALDONG_NM', 'PLOT_YN', 'HMNO_LTNO', 'HSNO_LTNO', 'LNNO_ADRES',
#        'XU_DIMS', 'LTOUT_DIMS', 'PLOT_DIMS', 'DONG_NM', 'BULD_FLR_NO', 'HO_NM',
#        'LA', 'LO', 'ESTT_CURPRC_SMNT_AMT', 'IMG_COURS', 'DATA_STRD_YM'],
#       dtype='object')

# %%
est[est['SIGNGU_NM']=='서울특별시 강남구'].groupby('DATA_STRD_YM').mean()['ESTT_CURPRC_SMNT_AMT']
# Out:
# <ipython-input-39-7fb3cabf017e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   est[est['SIGNGU_NM']=='서울특별시 강남구'].groupby('DATA_STRD_YM').mean()['ESTT_CURPRC_SMNT_AMT']
# DATA_STRD_YM
# 202212.0    61359.786963
# 202303.0    62047.195522
# 202306.0    60913.464347
# 202309.0    61628.970447
# Name: ESTT_CURPRC_SMNT_AMT, dtype: float64

# %%
move=pd.read_csv('/content/drive/MyDrive/부동산/시도_성_연령_5세_별_이동자수_20231122093216.csv')

# %%
move=move.drop('성별',axis=1)

# %%
move_df=pd.pivot(move,index=['행정구역(시도)별','연령별','시점'],columns='항목')

# %%
movein=move[move['항목']=='시도간전입 (명)']
moveout=move[move['항목']=='시도간전출 (명)']

# %%
movein
# Out:
#     행정구역(시도)별     연령별    시점         항목    데이터
# 0       서울특별시  0 - 4세  2015  시도간전입 (명)  17355
# 2       서울특별시  0 - 4세  2016  시도간전입 (명)  16117
# 4       서울특별시  0 - 4세  2017  시도간전입 (명)  15447
# 6       서울특별시  0 - 4세  2018  시도간전입 (명)  13914
# 8       서울특별시  0 - 4세  2019  시도간전입 (명)  13607
# ..        ...     ...   ...        ...    ...
# 262     서울특별시   80세이상  2018  시도간전입 (명)   7766
# 264     서울특별시   80세이상  2019  시도간전입 (명)   7930
# 266     서울특별시   80세이상  2020  시도간전입 (명)   8758
# 268     서울특별시   80세이상  2021  시도간전입 (명)   8207
# 270     서울특별시   80세이상  2022  시도간전입 (명)   6835
#
# [136 rows x 5 columns]

# %%
movein=movein.sort_values(['시점','연령별']).reset_index(drop=True)
moveout=moveout.sort_values(['시점','연령별']).reset_index(drop=True)

# %%
moveratio=movein['데이터']/moveout['데이터']

# %%
move_df=pd.concat([movein.loc[:,['행정구역(시도)별','연령별','시점']],moveratio],axis=1).rename(columns={'데이터':'이동비율'})

# %%
# Out:
#     행정구역(시도)별       연령별    시점      이동비율
# 0       서울특별시    0 - 4세  2015  0.519440
# 1       서울특별시  10 - 14세  2015  0.811418
# 2       서울특별시  15 - 19세  2015  1.034508
# 3       서울특별시  20 - 24세  2015  1.297894
# 4       서울특별시  25 - 29세  2015  1.042631
# ..        ...       ...   ...       ...
# 131     서울특별시  60 - 64세  2022  0.652525
# 132     서울특별시  65 - 69세  2022  0.639305
# 133     서울특별시  70 - 74세  2022  0.635059
# 134     서울특별시  75 - 79세  2022  0.642989
# 135     서울특별시     80세이상  2022  0.635459
#
# [136 rows x 4 columns]

# %%
sns.lineplot(data=move_df,x='연령별',y='이동비율',hue='시점',legend='full',palette=sns.color_palette('Paired',8))
plt.axhline(1,color='grey')
plt.xticks(rotation=90)
plt.show()

# %%
move_df
# Out:
#     행정구역(시도)별       연령별    시점      이동비율
# 0       서울특별시    0 - 4세  2015  0.519440
# 1       서울특별시  10 - 14세  2015  0.811418
# 2       서울특별시  15 - 19세  2015  1.034508
# 3       서울특별시  20 - 24세  2015  1.297894
# 4       서울특별시  25 - 29세  2015  1.042631
# ..        ...       ...   ...       ...
# 131     서울특별시  60 - 64세  2022  0.652525
# 132     서울특별시  65 - 69세  2022  0.639305
# 133     서울특별시  70 - 74세  2022  0.635059
# 134     서울특별시  75 - 79세  2022  0.642989
# 135     서울특별시     80세이상  2022  0.635459
#
# [136 rows x 4 columns]

# %%
det_seoul=detach[detach['SIDO_NM']=='서울특별시']

# %%
mul_seoul.head()
# Out:
#    RHMH_HOUSE_MTHT_CONV_RATE_INFO_NO SIDO_NM SIGNGU_NM TNSHP_NM EMD_NM  \
# 0                                  1   서울특별시       강남구      NaN    개포동
# 1                                  2   서울특별시       강남구      NaN    개포동
# 2                                  3   서울특별시       강남구      NaN    개포동
# 3                                  4   서울특별시       강남구      NaN    개포동
# 4                                  5   서울특별시       강남구      NaN    개포동
#
#     HONO_NM  SMOEU  CNTRCT_YM  CNTRCT_DE  MTHT_GTN  MNTH_RENTCG  FLR  \
# 0  \t1201-7  22.95     202208   20220818        87          7.0    4
# 1  \t1263-7  47.15     202208   20220813       318          1.0    4
# 2  \t169-11  38.21     202208   20220825        52          2.0    2
# 3  \t660-35  14.80     202207   20220714        68          3.0    4
# 4  \t1193-2  40.52     202209   20220924        25          3.0    4
#
#    BILDNG_YR CNTRCT_CLSF_NM SUSAR_NM  NMHSH AVE_LFSTS_PC_MINM_AMT  \
# ...

# %%
det_seoul.head()
# Out:
#    DTCHDHS_MTHT_CONV_RT_INFO_NO SIDO_NM SIGNGU_NM TNSHP_NM EMD_NM  \
# 0                             1   서울특별시       강남구      NaN    개포동
# 1                             2   서울특별시       강남구      NaN    개포동
# 2                             3   서울특별시       강남구      NaN    개포동
# 3                             4   서울특별시       강남구      NaN    개포동
# 4                             5   서울특별시       강남구      NaN    개포동
#
#   NRB_ROAD_BT_CONT  CNTRCT_DIMS_SQM_VL  CNTRCT_YM  CNTRCT_DE  MTHT_GTN  \
# 0             8m미만               14.04     202208   20220824        36
# 1             8m미만               18.00     202207   20220722         6
# 2             8m미만               22.00     202207   20220721       136
# 3             8m미만               22.00     202207   20220722       136
# 4             8m미만               22.00     202209   20220927        45
#
#    MNTH_RENTCG  BILDNG_YR CNTRCT_CLSF_NM  AVE_LFSTS_PC_MINM_AMT  \
# 0          3.0       1996            NaN                    420
# ...

# %%
est
# Out:
#           index CTPR_CD CTPR_NM  SIGNGU_CD  SIGNGU_NM  LEGALDONG_CD  \
# 0             0      11   서울특별시    11110.0  서울특별시 종로구       11100.0
# 1             1      11   서울특별시    11110.0  서울특별시 종로구       11100.0
# 2             2      11   서울특별시    11110.0  서울특별시 종로구       11100.0
# 3             3      11   서울특별시    11110.0  서울특별시 종로구       11100.0
# 4             4      11   서울특별시    11110.0  서울특별시 종로구       11100.0
# ...         ...     ...     ...        ...        ...           ...
# 2546825  640801      11   서울특별시    11740.0  서울특별시 강동구       10900.0
# 2546826  640802      11   서울특별시    11740.0  서울특별시 강동구       10900.0
# 2546827  640803      11   서울특별시    11740.0  서울특별시 강동구       10900.0
# 2546828  640804      11   서울특별시    11740.0  서울특별시 강동구       10900.0
# 2546829  640805      11   서울특별시    11740.0  서울특별시 강동구       10900.0
#
#          LEGALDONG_NM  PLOT_YN  HMNO_LTNO  HSNO_LTNO  ... LTOUT_DIMS  \
# 0                 NaN      1.0       19.0       35.0  ...      68.07
# ...

# %%
cha_seoul
# Out:
#              MTHT_GTN  MNTH_RENTCG
# SIGNGU_NM
# 강남구        192.663900     2.545837
# 강동구        205.306771     1.628617
# 강북구         97.050413     1.661538
# 강서구        143.206734     1.746515
# 관악구        251.610351     1.772323
# 광진구        228.385438     2.002388
# 구로구        104.912188     1.309576
# 금천구        140.754141     1.621584
# 노원구        111.317047     1.792565
# 도봉구        101.866890     1.361605
# 동대문구       148.720839     2.369943
# 동작구        193.872474     1.919353
# 마포구        159.552302     2.194697
# 서대문구       122.369034     1.894470
# 서초구        246.919612     2.135562
# 성동구        197.303639     2.009975
# 성북구        136.938894     1.988850
# 송파구        220.662277     1.678272
# 양천구        155.710466     1.496729
# 영등포구       227.732461     2.093239
# 용산구        160.964984     2.154397
# 은평구        135.394112     1.528122
# 종로구        131.761484     1.594111
# 중구         147.822119     2.040603
# 중랑구        192.954334     1.907922

# %%
mul_s_df=mul_seoul.groupby(['SIGNGU_NM','EMD_NM']).mean().loc[:,['MTHT_GTN','MNTH_RENTCG']].reset_index()
# Out:
# <ipython-input-30-8dd7a9557813>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mul_s_df=mul_seoul.groupby(['SIGNGU_NM','EMD_NM']).mean().loc[:,['MTHT_GTN','MNTH_RENTCG']].reset_index()

# %%
mul_s_df
# Out:
#     SIGNGU_NM EMD_NM    MTHT_GTN  MNTH_RENTCG
# 0         강남구    개포동  238.829953     2.008268
# 1         강남구    논현동  156.985975     3.015428
# 2         강남구    대치동  194.363844     2.319756
# 3         강남구    도곡동  293.286344     2.144934
# 4         강남구    삼성동  151.786773     2.352452
# ..        ...    ...         ...          ...
# 315       중랑구    면목동  181.632492     2.084306
# 316       중랑구     묵동  209.964657     1.536383
# 317       중랑구    상봉동  248.510989     2.101832
# 318       중랑구    신내동  243.898734     1.018987
# 319       중랑구    중화동  171.607143     1.691295
#
# [320 rows x 4 columns]

# %%
mul_s_df=pd.melt(mul_s_df,id_vars=['SIGNGU_NM','EMD_NM'],value_vars=['MTHT_GTN','MNTH_RENTCG']).rename(columns={'variable':'CG_TYPE','value':'CG'})

# %%
mul_s_df
# Out:
#     SIGNGU_NM EMD_NM      CG_TYPE          CG
# 0         강남구    개포동     MTHT_GTN  238.829953
# 1         강남구    논현동     MTHT_GTN  156.985975
# 2         강남구    대치동     MTHT_GTN  194.363844
# 3         강남구    도곡동     MTHT_GTN  293.286344
# 4         강남구    삼성동     MTHT_GTN  151.786773
# ..        ...    ...          ...         ...
# 635       중랑구    면목동  MNTH_RENTCG    2.084306
# 636       중랑구     묵동  MNTH_RENTCG    1.536383
# 637       중랑구    상봉동  MNTH_RENTCG    2.101832
# 638       중랑구    신내동  MNTH_RENTCG    1.018987
# 639       중랑구    중화동  MNTH_RENTCG    1.691295
#
# [640 rows x 4 columns]

# %%
GTN=StandardScaler().fit_transform(np.array(mul_s_df[mul_s_df['CG_TYPE']=='MTHT_GTN']['CG']).reshape(-1,1))
RENTCG=StandardScaler().fit_transform(np.array(mul_s_df[mul_s_df['CG_TYPE']=='MNTH_RENTCG']['CG']).reshape(-1,1))

# %%
mul_s_df=mul_s_df.sort_values('SIGNGU_NM').reset_index()

# %%
mul_s_df=mul_s_df.drop('index',axis=1)

# %%
mul_s_df['SIGNGU_NM'].unique()
# Out:
# array(['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구',
#        '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'], dtype=object)

# %%
mul_s_df=pd.concat([mul_s_df,pd.concat([pd.DataFrame(GTN),pd.DataFrame(RENTCG)]).rename(columns={0:'CG_STD'}).reset_index(drop=True)],axis=1)

# %%
mul_seoul[mul_seoul['SIGNGU_NM']=='금천구'].EMD_NM.unique()
# Out:
# array(['가산동', '독산동', '시흥동'], dtype=object)

# %%
mul_s_df[mul_s_df['SIGNGU_NM']=='금천구'].EMD_NM.unique()
# Out:
# array(['가산동', '독산동', '시흥동'], dtype=object)

# %%
fig,ax=plt.subplots(nrows=25,figsize=(20,300))
for i in range(len(mul_s_df['SIGNGU_NM'].unique())):
    sns.lineplot(mul_s_df[mul_s_df['SIGNGU_NM']==mul_s_df['SIGNGU_NM'].unique()[i]],x='EMD_NM',y='CG_STD',hue='CG_TYPE',ax=ax[i])
for ax in plt.gcf().axes:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90,fontsize=15)

# 그래프 표시
plt.show()
# Out:
# <ipython-input-251-151bc735466d>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90,fontsize=15)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
mul_s_df.groupby(['SIGNGU_NM','EMD_NM']).mean().reset_index()
# Out:
# <ipython-input-268-c50fe249c721>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mul_s_df.groupby(['SIGNGU_NM','EMD_NM']).mean().reset_index()
#     SIGNGU_NM EMD_NM          CG    CG_STD
# 0         강남구    개포동  120.419111  0.273620
# 1         강남구    논현동   80.000701  0.523777
# 2         강남구    대치동   98.341800  0.264581
# 3         강남구    도곡동  147.715639  0.603322
# 4         강남구    삼성동   77.069612  0.092618
# ..        ...    ...         ...       ...
# 315       중랑구    면목동   91.858399  0.062356
# 316       중랑구     묵동  105.750520 -0.146786
# 317       중랑구    상봉동  125.306410  0.374830
# 318       중랑구    신내동  122.458861 -0.311884
# 319       중랑구    중화동   86.649219 -0.224556
#
# [320 rows x 4 columns]

# %%
mul_s_df
# Out:
#     SIGNGU_NM EMD_NM      CG_TYPE          CG    CG_STD
# 0         강남구    개포동     MTHT_GTN  238.829953  0.535078
# 1         강남구    세곡동  MNTH_RENTCG    2.122222  0.152316
# 2         강남구    신사동  MNTH_RENTCG    2.472689  0.583363
# 3         강남구    역삼동  MNTH_RENTCG    2.634420  0.782280
# 4         강남구    율현동  MNTH_RENTCG    0.800000 -1.473914
# ..        ...    ...          ...         ...       ...
# 635       중랑구     묵동     MTHT_GTN  209.964657  0.274649
# 636       중랑구    면목동     MTHT_GTN  181.632492  0.019030
# 637       중랑구    망우동     MTHT_GTN  146.050378 -0.302000
# 638       중랑구    신내동  MNTH_RENTCG    1.018987 -1.204577
# 639       중랑구    중화동  MNTH_RENTCG    1.691295 -0.377691
#
# [640 rows x 5 columns]

# %%
sns.boxplot(mul_s_df[mul_s_df['CG_TYPE']=='MTHT_GTN'],x='SIGNGU_NM',y='CG_STD')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.boxplot(mul_s_df[mul_s_df['CG_TYPE']=='MNTH_RENTCG'],x='SIGNGU_NM',y='CG_STD')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
station=pd.read_csv('/content/drive/MyDrive/부동산/서울시 역사마스터 정보.csv',encoding='cp949')

# %%
station['호선'].unique()
# Out:
# array(['5호선', '김포골드라인', '서해선', '우이신설선', '의정부선', '에버라인선', '신림선',
#        '신분당선(연장)', '신분당선', '신분당선(연장2)', '공항철도1호선', '9호선(연장)', '9호선',
#        '7호선', '7호선(인천)', '인천2호선', '인천1호선', '8호선', '6호선', '일산선', '경원선',
#        '수인선', '분당선', '경인선', '안산선', '경부선', '경강선', '과천선', '장항선', '경춘선',
#        '경의중앙선', '중앙선', '4호선', '진접선', '3호선', '2호선', '1호선'], dtype=object)

# %%
import folium

# %%
len(station['호선'].unique())
# Out:
# 33

# %%
pd.DataFrame(station['호선'].unique()).sort_values(0)
# Out:
#           0
# 32      1호선
# 31      2호선
# 30      3호선
# 28      4호선
# 0       5호선
# 14      6호선
# 10      7호선
# 13      8호선
# 9       9호선
# 22      경강선
# 21      경부선
# 16      경원선
# 26    경의중앙선
# 19      경인선
# 25      경춘선
# 8   공항철도1호선
# 23      과천선
# 1    김포골드라인
# 18      분당선
# 2       서해선
# 17      수인선
# 6       신림선
# 7      신분당선
# 20      안산선
# 5     에버라인선
# 3     우이신설선
# 4      의정부선
# 12    인천1호선
# 11    인천2호선
# 15      일산선
# 24      장항선
# 27      중앙선
# 29      진접선

# %%
station.iloc[station[station['호선'].str.contains('9호선')].index,2]='9호선'

# %%
station.iloc[station[station['호선'].str.contains('7호선')].index,2]='7호선'

# %%
station.iloc[station[station['호선'].str.contains('신분당선')].index,2]='신분당선'

# %%
station
# Out:
#      역사_ID   역사명      호선         위도          경도
# 0     9996    미사     5호선  37.560927  127.193877
# 1     9995    강일     5호선  37.557490  127.175930
# 2     4929  김포공항  김포골드라인  37.562360  126.801868
# 3     4928    고촌  김포골드라인  37.601243  126.770345
# 4     4927    풍무  김포골드라인  37.612488  126.732387
# ..     ...   ...     ...        ...         ...
# 763    154  종로5가     1호선  37.570926  127.001849
# 764    153  종로3가     1호선  37.570406  126.991847
# 765    152    종각     1호선  37.570161  126.982923
# 766    151    시청     1호선  37.565715  126.977088
# 767    150   서울역     1호선  37.556228  126.972135
#
# [768 rows x 5 columns]

# %%
e_seoul.columns
# Out:
# Index(['TRDAR_NO', 'TRDAR_NM', 'CTPR_CD', 'CTPR_NM', 'SIGNGU_CD', 'SIGNGU_NM',
#        'TRDAR_ISE_TOTL_BILD_CNT', 'TRDAR_ISE_1KIND_NGHBRHD_LVLH_FCLTY_CNT',
#        'TRDAR_ISE_2KIND_NGHBRHD_LVLH_FCLTY_CNT',
#        'TRDAR_ISE_CLTUR_AND_MTNG_FCLTY_CNT', 'TRDAR_ISE_RLGN_LVLH_FCLTY_CNT',
#        'TRDAR_ISE_NTSL_FCLTY_CNT', 'TRDAR_ISE_MLFLT_CNT',
#        'TRDAR_ISE_OVNTY_FCLTY_CNT', 'TRDAR_ISE_NVTT_FCLTY_CNT',
#        'TRDAR_ISE_EXRCS_FCLTY_CNT', 'TRDAR_ISE_ACMT_CNT',
#        'TRDAR_ISE_WAF_FCLTY_CNT', 'TRDAR_ISE_GAS_TOTL_USQNT',
#        'TRDAR_ISE_FTRM_TOTL_USQNT', 'CMRC_PUP_BULD_GAS_USQNT',
#        'CMRC_PUP_BULD_FTRM_USQNT', 'TRDAR_CRDNT_CONT', 'DATA_STRD_YM'],
#       dtype='object')
